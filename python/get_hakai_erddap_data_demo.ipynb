# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Download data
# This code download the last two years of data from QU39 and generate and pandas dataframe

# %%
# Let's download the last two montsh of data from QU39 in a csv format
url = 'https://catalogue.hakai.org/erddap/tabledap/HakaiWaterPropertiesInstrumentProfileProvisional.csv?&station="QU39"&time>now-2years';

# Load data and ignore the second row which is the units associated with each columns in ERDDAP csv format
df = pd.read_csv(url, skiprows=[1])
df.head()
# Out:
# <ipython-input-9-814feb74c14c>:5: DtypeWarning:
#
# Columns (8,26,29,32,35,38,41,44,47,50,53,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   work_area cruise                        hakai_id       vessel  \
# 0    QUADRA  QOMA5  18032_2021-04-19T17:42:05.834Z  HAKAI SCOUT
# 1    QUADRA  QOMA5  18032_2021-04-19T17:42:05.834Z  HAKAI SCOUT
# 2    QUADRA  QOMA5  18032_2021-04-19T17:42:05.834Z  HAKAI SCOUT
# 3    QUADRA  QOMA5  18032_2021-04-19T17:42:05.834Z  HAKAI SCOUT
# 4    QUADRA  QOMA5  18032_2021-04-19T17:42:05.834Z  HAKAI SCOUT
#
#                    operators comments device_model  device_sn device_firmware  \
# 0  eva.jordison,meagan.abele      NaN      XRX-620      18032            6.81
# 1  eva.jordison,meagan.abele      NaN      XRX-620      18032            6.81
# 2  eva.jordison,meagan.abele      NaN      XRX-620      18032            6.81
# 3  eva.jordison,meagan.abele      NaN      XRX-620      18032            6.81
# 4  eva.jordison,meagan.abele      NaN      XRX-620      18032            6.81
#
#   cast_processing_stage  ... c_star_at_flag_description  ph  ph_UQL  \
# 0              10_qc_pi  ...                        NaN NaN     NaN
# 1              10_qc_pi  ...                        NaN NaN     NaN
# 2              10_qc_pi  ...                        NaN NaN     NaN
# 3              10_qc_pi  ...                        NaN NaN     NaN
# 4              10_qc_pi  ...                        NaN NaN     NaN
#
#    cph_flag_description  backscatter_beta backscatter_beta_UQL  \
# 0                   NaN               NaN                  NaN
# 1                   NaN               NaN                  NaN
# 2                   NaN               NaN                  NaN
# 3                   NaN               NaN                  NaN
# 4                   NaN               NaN                  NaN
#
#   backscatter_beta_flag_description cdom_ppb cdom_ppb_UQL  \
# 0                               NaN      NaN          NaN
# 1                               NaN      NaN          NaN
# 2                               NaN      NaN          NaN
# 3                               NaN      NaN          NaN
# 4                               NaN      NaN          NaN
#
#    cdom_flag_description
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Generate Figures

# %% [markdown]
# ### Plotly express scatter timeseries

# %%
fig = px.scatter(df,x='time',y='depth',color='temperature',range_color=[6,12])
fig.update_yaxes(autorange='reversed')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="50a6a831-7411-4606-95e7-5d4f74f326ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50a6a831-7411-4606-95e7-5d4f74f326ff")) {                    Plotly.newPlot(                        "50a6a831-7411-4606-95e7-5d4f74f326ff",                        [{"hovertemplate":"time=%{x}<br>depth=%{y}<br>temperature=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":